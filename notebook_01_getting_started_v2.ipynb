# %% [markdown]
# <a href="https://colab.research.google.com/github/Vannessagmz/Ejercicios-de-Bioinformatica/blob/main/notebook_01_getting_started_v2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [raw]
# ---
# title: Getting Started con Python
# subtitle: Python Crash Course — Capítulo 1 (Para quienes ya saben R)
# author: Roberto Álvarez Basado en Eric Matthes
# format:
#   html:
#     toc: true
#     toc-depth: 4
#     code-fold: false
#     highlight-style: github
#     theme: cosmo
#   pdf:
#     toc: true
# ---

# %% [markdown]
# > **Nivel:** Programadores con experiencia en R (básico-intermedio)\
# > **Capítulo:** 1 — Primeros pasos\
# > **Tiempo estimado:** 90-120 minutos
#
# ---
#
# ## 🎯 Objetivos del Capítulo
#
# Al terminar este capítulo serás capaz de:
#
# - Ejecutar tu primer programa Python desde cero
# - Usar el intérprete interactivo de Python
# - Identificar las diferencias clave entre Python y R en sintaxis básica
# - Realizar operaciones aritméticas y entender el sistema de tipos numéricos
# - Escribir comentarios claros y código bien documentado
# - Evitar los errores más comunes al comenzar en Python
#
# ---
#
# ## 🗺️ Mapa del Capítulo
#
# ```
# 1.1 El Entorno Python
#     └── Intérprete interactivo vs scripts
# 1.2 Tu Primer Programa
#     └── print() en detalle
# 1.3 Python como Calculadora
#     └── Tipos numéricos y operadores
# 1.4 Variables y Asignación
#     └── Diferencias con R
# 1.5 Comentarios y Documentación
#     └── Buenas prácticas
# 1.6 Errores Comunes
# 📝 Ejercicios Graduales
# 🚀 Mini Proyecto
# 🏆 Desafíos
# ```
#
# ---
#
# ## 🔄 Python vs R: La Perspectiva General
#
# Antes de escribir código, entendamos las diferencias de mentalidad:
#
# | Aspecto | R | Python |
# |---|---|---|
# | Propósito original | Estadística y análisis | Programación general |
# | Paradigma dominante | Funcional / vectorizado | Orientado a objetos |
# | Sintaxis de bloques | `{ }` | Indentación obligatoria |
# | Terminador de línea | Opcional (newline) | Newline (sin `;`) |
# | Índices | Comienzan en **1** | Comienzan en **0** |
# | Asignación | `<-` (preferido) o `=` | Solo `=` |
# | NULL / nada | `NULL` | `None` |
# | Valor verdadero | `TRUE` / `FALSE` | `True` / `False` |
# | Comentarios | `#` | `#` ✅ (igual) |
# | Documentación inline | Roxygen `#'` | Docstrings `"""` |
#
# ::: {.callout-tip title="💡 Mentalidad Clave"}
# En R todo está vectorizado por defecto — operás sobre vectores completos sin pensar.
# En Python el comportamiento por defecto es **escalar** (elemento a elemento). Para vectorización necesitás NumPy o pandas.
# Esto no es mejor ni peor, es diferente. Lo veremos en profundidad en capítulos posteriores.
# :::
#
# ---

# %% [markdown]
# ## 1.1 El Entorno Python
#
# ### 1.1.1 Modos de ejecutar Python
#
# Al igual que en R tenés RStudio con consola y scripts, en Python tenés:
#
# | Modo | Equivalente en R | Cuándo usarlo |
# |---|---|---|
# | Intérprete interactivo (`python`) | Consola de R | Exploración rápida |
# | Script `.py` | Script `.R` | Código en producción |
# | Jupyter Notebook `.ipynb` | R Markdown / Quarto | Análisis + narrativa |
# | IPython | Consola de RStudio | Interactivo mejorado |
#
# ### 1.1.2 Verificar tu instalación
#
# En terminal (equivalente a `R --version` en R):

# %%
# Verificar la versión de Python desde dentro del propio Python
import sys
print(f"Python versión: {sys.version}")
print(f"Versión mayor: {sys.version_info.major}")
print(f"Versión menor: {sys.version_info.minor}")
# Out:
# Python versión: 3.12.13 (main, Mar  4 2026, 09:23:07) [GCC 11.4.0]
# Versión mayor: 3
# Versión menor: 12

# %% [markdown]
# ::: {.callout-note title="R vs Python"}
# ```r
# # En R para ver la versión:
# R.version.string
# # o
# version$major
# ```
# ```python
# # En Python:
# import sys
# sys.version
# ```
# :::
#
# ---
#
# ## 1.2 Tu Primer Programa
#
# ### 1.2.1 El clásico "Hola Mundo"

# %%
# La función print() muestra texto en pantalla
# En R también existe print(), cat(), y message() — aquí solo existe print() para esto
print("¡Hola, Python!")
# Out:
# ¡Hola, Python!

# %% [markdown]
# ### 1.2.2 `print()` en detalle
#
# La función `print()` en Python es más explícita que en R. En R, escribir una expresión en la consola la imprime automáticamente. En Python **necesitás llamar `print()` explícitamente** (excepto en el intérprete interactivo).

# %%
# Múltiples argumentos — print() los separa con espacio por defecto
print("Nombre:", "Vanne", "Edad:", 31)

# Cambiar el separador (sep)
print("2026", "03", "12", sep="-")    # Output: 2024-03-15
print("a", "b", "c", sep="|")

# Cambiar el final de línea (end) — por defecto es "\n"
print("Esto no tiene salto de línea", end="")
print(" — continúa aquí")

# Imprimir línea vacía
print()  # Solo imprime un newline
# Out:
# Nombre: Vanne Edad: 31
# 2026-03-12
# a|b|c
# Esto no tiene salto de línea — continúa aquí

# %% [markdown]
# ::: {.callout-note title="R vs Python — print()"}
# ```r
# # En R, cat() es más parecido al print() de Python
# cat("Nombre:", "Ana", "Edad:", 30, "\n")   # sep=" " por defecto
# cat("2024", "03", "15", sep="-")
#
# # paste() para construir strings
# paste("a", "b", "c", sep="|")
# ```
# ```python
# # En Python todo es con print()
# print("Nombre:", "Ana", "Edad:", 30)       # sep=" " por defecto
# print("2024", "03", "15", sep="-")
# ```
# :::
#
# ### 1.2.3 Strings: comillas simples vs dobles
#
# Python acepta ambas — son equivalentes. Convención: usar comillas dobles para texto, simples para caracteres individuales o cuando el texto contiene apóstrofos.

# %%
# Ambas son equivalentes en Python (a diferencia de algunos lenguajes)
saludo1 = "Hola, mundo"
saludo2 = 'Hola, mundo'

print(saludo1 == saludo2)    # True

# Útil cuando el texto contiene comillas
frase1 = "Python es 'fácil' de aprender"
frase2 = 'Python es "poderoso"'

print(frase1)
print(frase2)
# Out:
# True
# Python es 'fácil' de aprender
# Python es "poderoso"

# %% [markdown]
# ---
#
# ## 1.3 Python como Calculadora
#
# ### 1.3.1 Operadores aritméticos básicos

# %%
# Operaciones aritméticas básicas
# La sintaxis es idéntica a R en casi todos los casos

print("--- Operaciones básicas ---")
print(2 + 3)      # Suma          → 5
print(10 - 4)     # Resta         → 6
print(10 * 5)     # Multiplicación → 50
print(17 / 3)     # División real  → 5.666... (siempre retorna float)

print("\n--- Operadores exclusivos de Python ---")
print(17 // 3)    # División entera → 5   (en R: 17 %/% 3)
print(17 % 3)     # Módulo (resto)  → 2   (en R: 17 %% 3)
print(2 ** 10)    # Potencia        → 1024 (en R: 2^10 o 2**10)
# Out:
# --- Operaciones básicas ---
# 5
# 6
# 50
# 5.666666666666667
#
# --- Operadores exclusivos de Python ---
# 5
# 2
# 1024

# %% [markdown]
# ::: {.callout-note title="R vs Python — Operadores"}
# | Operación | R | Python |
# |---|---|---|
# | División real | `17 / 3` → 5.67 | `17 / 3` → 5.67 ✅ igual |
# | División entera | `17 %/% 3` → 5 | `17 // 3` → 5 |
# | Módulo | `17 %% 3` → 2 | `17 % 3` → 2 |
# | Potencia | `2^10` o `2**10` | `2**10` (solo `**`) |
#
# ⚠️ En Python `^` es XOR (operación de bits), **no** potencia. ¡Cuidado!
# :::
#
# ### 1.3.2 Tipos numéricos en Python
#
# A diferencia de R donde casi todo es vector, Python tiene tipos escalares distintos:

# %%
# Python tiene 3 tipos numéricos principales

entero    = 42          # int   — equivalente a integer en R
decimal   = 3.14        # float — equivalente a numeric/double en R
complejo  = 3 + 2j      # complex — equivalente a complex en R

print(type(entero))     # <class 'int'>
print(type(decimal))    # <class 'float'>
print(type(complejo))   # <class 'complex'>

# type() en Python == class() en R
print("\n--- El tipo determina el resultado ---")
print(10 / 2)     # 5.0  → float (aunque sea divisible exacto)
print(10 // 2)    # 5    → int
print(type(10 / 2))   # float
print(type(10 // 2))  # int
# Out:
# <class 'int'>
# <class 'float'>
# <class 'complex'>
#
# --- El tipo determina el resultado ---
# 5.0
# 5
# <class 'float'>
# <class 'int'>

# %% [markdown]
# ### 1.3.3 Precisión numérica y números grandes
#
# Python maneja enteros de precisión arbitraria — algo que R no hace nativamente:

# %%
# Python maneja enteros enormes sin overflow
numero_enorme = 2 ** 100
print(f"2^100 = {numero_enorme}")
print(f"Dígitos: {len(str(numero_enorme))}")

# En R, 2^100 retorna Inf si se usa integer, o notación científica en double
# Python: sin límite en enteros

print("\n--- Floats tienen precisión limitada (IEEE 754) ---")
print(0.1 + 0.2)           # 0.30000000000000004 — igual que R!
print(0.1 + 0.2 == 0.3)    # False — ¡trampa clásica!

# La solución correcta
import math
print(math.isclose(0.1 + 0.2, 0.3))   # True — equivalente a all.equal() en R
# Out:
# 2^100 = 1267650600228229401496703205376
# Dígitos: 31
#
# --- Floats tienen precisión limitada (IEEE 754) ---
# 0.30000000000000004
# False
# True

# %% [markdown]
# ::: {.callout-warning title="⚠️ Trampa de Precisión Flotante"}
# Este problema existe en **todos** los lenguajes (R, Python, JavaScript, C...).
# La regla: **nunca compares floats con `==`**. Usá `math.isclose()` en Python o `all.equal()` en R.
# :::
#
# ### 1.3.4 Operaciones combinadas y precedencia

# %%
# La precedencia es la misma que en matemáticas (y en R)
# PEMDAS: Paréntesis, Exponentes, Multiplicación/División, Suma/Resta

resultado1 = 2 + 3 * 4        # 14, no 20
resultado2 = (2 + 3) * 4      # 20
resultado3 = 2 ** 3 ** 2      # 512 = 2^(3^2) = 2^9  (potencia: derecha a izquierda)

print(f"2 + 3 * 4     = {resultado1}")
print(f"(2 + 3) * 4   = {resultado2}")
print(f"2 ** 3 ** 2   = {resultado3}")

# Fórmula real: distancia euclidiana
x1, y1 = 0, 0
x2, y2 = 3, 4
distancia = ((x2 - x1) ** 2 + (y2 - y1) ** 2) ** 0.5
print(f"\nDistancia entre (0,0) y (3,4): {distancia}")
# Out:
# 2 + 3 * 4     = 14
# (2 + 3) * 4   = 20
# 2 ** 3 ** 2   = 512
#
# Distancia entre (0,0) y (3,4): 5.0

# %% [markdown]
# ---
#
# ## 1.4 Variables y Asignación
#
# ### 1.4.1 Asignación básica

# %%
# En Python solo se usa = para asignar (no <- como en R)
nombre = "Vannessa"
edad = 31
altura = 1.64
es_estudiante = True    # Nótese la mayúscula inicial (True, no TRUE como en R)

print(nombre)
print(edad)
print(altura)
print(es_estudiante)

# Verificar tipo de cada variable
print(f"\nTipos:")
print(f"  nombre:        {type(nombre)}")
print(f"  edad:          {type(edad)}")
print(f"  altura:        {type(altura)}")
print(f"  es_estudiante: {type(es_estudiante)}")
# Out:
# Vannessa
# 31
# 1.64
# True
#
# Tipos:
#   nombre:        <class 'str'>
#   edad:          <class 'int'>
#   altura:        <class 'float'>
#   es_estudiante: <class 'bool'>

# %% [markdown]
# ::: {.callout-note title="R vs Python — Asignación"}
# ```r
# # R (preferido usar <-)
# nombre <- "Valentina"
# edad   <- 28
# es_verdad <- TRUE    # Mayúsculas completas
#
# # R también acepta = pero es mala práctica dentro de scripts
# nombre = "Valentina"   # Funciona pero evitar
# ```
# ```python
# # Python (solo =)
# nombre = "Valentina"
# edad   = 28
# es_verdad = True     # Solo inicial en mayúscula
# ```
# :::
#
# ### 1.4.2 Asignación múltiple y simultánea
#
# Python tiene formas elegantes de asignar múltiples variables a la vez:

# %%
# Asignación múltiple en una línea (unpacking)
x, y, z = 10, 20, 30
print(f"x={x}, y={y}, z={z}")

# Intercambiar valores — elegante en Python, sin variable temporal
a, b = 5, 8
print(f"Antes: a={a}, b={b}")
a, b = b, a       # Swap!
print(f"Después: a={a}, b={b}")

# Asignar el mismo valor a múltiples variables
p = q = r = 0
print(f"p={p}, q={q}, r={r}")
# Out:
# x=10, y=20, z=30
# Antes: a=5, b=8
# Después: a=8, b=5
# p=0, q=0, r=0

# %% [markdown]
# ::: {.callout-note title="R vs Python — Swap de variables"}
# ```r
# # En R necesitás una variable temporal
# a <- 5; b <- 8
# temp <- a
# a <- b
# b <- temp
# ```
# ```python
# # Python lo hace en una línea (tuple unpacking)
# a, b = 5, 8
# a, b = b, a    # ✨ más elegante
# ```
# :::
#
# ### 1.4.3 Convenciones de nombres
#
# Python tiene convenciones estrictas (PEP 8):

# %%
# ✅ Nombres válidos y convenciones PEP 8
nombre_usuario    = "carlos"      # snake_case — estándar en Python
edad_minima       = 18
MAX_INTENTOS      = 3             # CONSTANTES en mayúsculas
_variable_interna = "privada"     # _ al inicio = convención de "privado"

# ✅ Python distingue mayúsculas de minúsculas (como R)
radio = 5
Radio = 10
RADIO = 15
print(radio, Radio, RADIO)    # Son tres variables distintas

# ❌ Nombres inválidos (generan SyntaxError)
# 2variable = 10      # No puede empezar con número
# mi-variable = 10    # Guiones NO (solo guiones bajos _)
# for = 10            # Palabras reservadas del lenguaje
# Out:
# 5 10 15

# %% [markdown]
# ::: {.callout-note title="R vs Python — Convenciones de nombres"}
# | Estilo | R | Python |
# |---|---|---|
# | snake_case | ✅ Común | ✅ Estándar (PEP 8) |
# | camelCase | ✅ Común en R base | ⚠️ Solo para clases |
# | punto.separado | ✅ Muy común en R | ❌ Evitar en Python |
# | MAYUSCULAS | Variables de entorno | Constantes |
#
# R acepta `mi.variable` (con punto). Python lo interpreta como acceso a atributo (`mi.variable` = atributo `variable` del objeto `mi`). **Nunca uses punto en nombres de variables Python.**
# :::
#
# ---
#
# ## 1.5 Comentarios y Documentación
#
# ### 1.5.1 Comentarios de una línea

# %%
# Comentario de una línea — idéntico a R
x = 5   # También al final de una línea de código

# En Python NO existe /* comentario multilínea */ como en C/Java
# Se usan múltiples # líneas

# Buenos comentarios explican el POR QUÉ, no el QUÉ
# ❌ Malo:
x = x + 1    # suma 1 a x

# ✅ Bueno:
x = x + 1    # ajusta por índice base-0

print(x)
# Out:
# 7

# %% [markdown]
# ### 1.5.2 Strings multilínea como comentarios de bloque

# %%
'''
Esto es un string multilínea con comillas simples.
Se usa como comentario de bloque por convención,
aunque técnicamente es un literal de string sin asignar.
El intérprete lo evalúa pero no hace nada con él.
'''

"""
Esta es la forma preferida para docstrings (documentación de funciones).
Las funciones en Python tienen su documentación dentro de ellas,
a diferencia de Roxygen en R que va ANTES de la función.
"""

# Ejemplo de función con docstring (adelanto del capítulo 3)
def calcular_area(radio):
    """
    Calcula el área de un círculo.

    Args:
        radio (float): El radio del círculo.

    Returns:
        float: El área del círculo.
    """
    return 3.14159 * radio ** 2

# Acceder a la documentación
help(calcular_area)
# Out:
# Help on function calcular_area in module __main__:
#
# calcular_area(radio)
#     Calcula el área de un círculo.
#
#     Args:
#         radio (float): El radio del círculo.
#
#     Returns:
#         float: El área del círculo.

# %% [markdown]
# ::: {.callout-note title="R vs Python — Documentación"}
# ```r
# # En R, Roxygen2 va ANTES de la función
# #' Calcula el área de un círculo
# #' @param radio El radio del círculo
# #' @return El área del círculo
# calcular_area <- function(radio) {
#   pi * radio^2
# }
# ```
# ```python
# # En Python, el docstring va DENTRO de la función
# def calcular_area(radio):
#     """Calcula el área de un círculo.
#
#     Args:
#         radio (float): El radio.
#     Returns:
#         float: El área.
#     """
#     return 3.14159 * radio ** 2
# ```
# :::
#
# ---
#
# ## 1.6 F-Strings: Interpolación de Variables
#
# Las f-strings son el equivalente moderno de `paste()` / `sprintf()` en R:

# %%
nombre = "Martín"
edad = 32
pi = 3.14159265

# F-string básica — prefijo f antes de las comillas
print(f"Hola, {nombre}! Tenés {edad} años.")

# Expresiones dentro de las llaves
print(f"El doble de tu edad es {edad * 2}")
print(f"En 10 años tendrás {edad + 10} años")

# Formato numérico
print(f"Pi redondeado a 2 decimales: {pi:.2f}")
print(f"Pi redondeado a 4 decimales: {pi:.4f}")
print(f"Número con separador de miles: {1234567:,}")
print(f"Porcentaje: {0.856:.1%}")

# Alineación de texto
print(f"{'Izquierda':<20}|{'Centro':^20}|{'Derecha':>20}")
# Out:
# Hola, Martín! Tenés 32 años.
# El doble de tu edad es 64
# En 10 años tendrás 42 años
# Pi redondeado a 2 decimales: 3.14
# Pi redondeado a 4 decimales: 3.1416
# Número con separador de miles: 1,234,567
# Porcentaje: 85.6%
# Izquierda           |       Centro       |             Derecha

# %% [markdown]
# ::: {.callout-note title="R vs Python — Interpolación de strings"}
# ```r
# # R tiene varias opciones:
# nombre <- "Martín"; pi_val <- 3.14159
#
# paste("Hola,", nombre)                          # paste()
# paste0("Hola, ", nombre, "!")                   # paste0() sin sep
# sprintf("Pi = %.2f", pi_val)                    # sprintf() con formato
# glue::glue("Hola, {nombre}!")                   # glue (más parecido a Python)
# ```
# ```python
# # Python moderno usa f-strings (Python 3.6+)
# f"Hola, {nombre}!"              # Lo más común hoy
# f"Pi = {pi_val:.2f}"            # Con formato
# ```
# Las f-strings de Python son muy similares al paquete `glue` de R.
# :::
#
# ---
#
# ## 1.7 Errores Comunes al Empezar
#
# ### 1.7.1 Error de indentación

# %%
# ✅ Correcto — Python usa indentación como estructura
x = 10
if x > 5:
    print("Mayor que 5")   # 4 espacios (o 1 tab)
    print("Este también")  # Mismo nivel = mismo bloque

print("Esto está fuera del if")  # Sin indentación = fuera del bloque

# En R esto sería:
# if (x > 5) {
#   print("Mayor que 5")
# }
# La indentación en R es opcional (pero buena práctica)
# Out:
# Mayor que 5
# Este también
# Esto está fuera del if

# %%
# Los errores más comunes — descomentá para ver el error

# 1. Usar ^ en lugar de ** para potencia
# resultado = 2^3    # Esto es XOR en Python, no potencia!
resultado = 2**3
print(f"2^3 = {resultado}")  # 8, correcto

# 2. Confundir True/False con TRUE/FALSE de R
# activo = TRUE    # NameError en Python
activo = True      # Correcto
print(f"Activo: {activo}")

# 3. Intentar concatenar string + número directamente
# print("Tengo" + 5 + "años")    # TypeError!
print("Tengo" + str(5) + " años")  # Correcto: convertir a str
print(f"Tengo {5} años")            # Mejor: usar f-string

# 4. División entera vs real (¡en R todo / es real!)
print(10 / 3)     # 3.333... (float)
print(10 // 3)    # 3 (int) — requiere // explícito
# Out:
# 2^3 = 8
# Activo: True
# Tengo5 años
# Tengo 5 años
# 3.3333333333333335
# 3

# %% [markdown]
# ::: {.callout-warning title="🚨 Tabla de Errores Clásicos: R → Python"}
# | Error | Código Erróneo | Código Correcto |
# |---|---|---|
# | Potencia | `2 ^ 3` | `2 ** 3` |
# | Booleanos | `TRUE`, `FALSE` | `True`, `False` |
# | Nada/null | `NULL` | `None` |
# | Asignación | `x <- 5` | `x = 5` |
# | Nombre con punto | `mi.var = 5` | `mi_var = 5` |
# | String + número | `"edad: " + edad` | `f"edad: {edad}"` |
# | Comparación float | `0.1 + 0.2 == 0.3` | `math.isclose(0.1+0.2, 0.3)` |
# :::
#
# ---
#
# ## 🧩 Sección de Buenas Prácticas

# %%
# ============================================================
# BUENAS PRÁCTICAS PEP 8 — Guía de estilo oficial de Python
# (Equivalente a la guía de estilo tidyverse en R)
# ============================================================

# 1. Espacios alrededor de operadores
x = 5 + 3       # ✅
x = 5+3         # ❌ (funciona, pero mala práctica)

# 2. Sin espacio entre función y paréntesis
print("Hola")   # ✅
# print ("Hola") # ❌ (espacio antes del paréntesis)

# 3. Líneas de máximo 79 caracteres
# Si una operación es larga, usá paréntesis para continuar en la siguiente línea
resultado = (10 + 20 +
             30 + 40)
print(resultado)

# 4. Dos líneas en blanco entre bloques principales
# (relevante cuando escribas funciones y clases)

# 5. Nombres descriptivos > abreviaciones
n = 0           # ❌ ¿Qué es n?
num_intentos = 0  # ✅ Claro y descriptivo

print("Código siguiendo PEP 8 es más fácil de mantener")
# Out:
# Hola
# 100
# Código siguiendo PEP 8 es más fácil de mantener

# %% [markdown]
# ---
#
# ## ✏️ Ejercicios Prácticos
#
# Los ejercicios están organizados en tres niveles de dificultad.
#
# ---
#
# ### 🟢 Nivel 1 — Fundamentos
#
# #### Ejercicio 1.1: Presentación Personal

# %%
# Ejercicio 1.1
# Crea variables para tu nombre, edad, ciudad y lenguaje previo.
# Luego imprimí una presentación usando f-strings.
# Ejemplo de output esperado:
# "Hola! Soy Ana, tengo 29 años, vivo en Querétaro y vengo de R"
#

# Tu código aquí:
nombre = "Vannessa"
edad = 31
ciudad = "Queretaro"
lenguaje_previo = "R"

# Completá esta línea:
print(f"Hola! Soy {nombre}, tengo {edad}, vivo en {ciudad}, anteriormente usaba {lenguaje_previo} para aprender a programar")
# Out:
# Hola! Soy Vannessa, tengo 31, vivo en Queretaro, anteriormente usaba R para aprender a programar

# %% [markdown]
# ::: {.callout-tip title="✅ Solución Ejercicio 1.1" collapse="true"}
# ```python
# nombre = "Ana García"
# edad = 29
# ciudad = "Querétaro"
# lenguaje_previo = "R"
#
# print(f"Hola! Soy {nombre}, tengo {edad} años, vivo en {ciudad} y vengo de {lenguaje_previo}.")
# ```
# :::
#
# #### Ejercicio 1.2: Operaciones con tu Edad

# %%
# Ejercicio 1.2
# Dado tu año de nacimiento, calcula y muestra:
# - Tu edad actual (asumí 2026)
# - Tu edad en 2030
# - El año en que cumplirás 100 años
# - Si sos mayor de edad (>= 18)

anio_nacimiento = 1995   # Cambiar por el tuyo
anio_actual = 2026

# Tu código aquí:
edad_actual = (anio_actual - anio_nacimiento)
print(edad_actual)
edad_2030 = (2030 - anio_nacimiento)
print (edad_2030)
edad_100 = (anio_nacimiento + 100)
print (edad_100)
mayor_de_edad = (edad_actual >= 18)
print ("Soy mayor de edad")
# Out:
# 31
# 35
# 2095
# Soy mayor de edad

# %% [markdown]
# ::: {.callout-tip title="✅ Solución Ejercicio 1.2" collapse="true"}
# ```python
# anio_nacimiento = 1995
# anio_actual = 2026
#
# edad_actual = anio_actual - anio_nacimiento
# edad_2030 = 2030 - anio_nacimiento
# anio_centenario = anio_nacimiento + 100
# es_mayor = edad_actual >= 18
#
# print(f"Edad actual: {edad_actual} años")
# print(f"Edad en 2030: {edad_2030} años")
# print(f"Cumplirás 100 años en: {anio_centenario}")
# print(f"¿Sos mayor de edad? {es_mayor}")
# ```
# :::
#
# #### Ejercicio 1.3: Conversión de Temperatura

# %%
# Ejercicio 1.3
# Convertí 100 grados Celsius a:
# - Fahrenheit: F = C × 9/5 + 32
# - Kelvin: K = C + 273.15
# Mostrá todos los resultados con 2 decimales

celsius = 100

# Tu código aquí:
celsius = 100
Fahrenheit = celsius * 9/5 + 32
print(Fahrenheit)
Kelvin = celsius + 273.15
print(Kelvin)

print(f"{celsius}°C = {Fahrenheit:.2f}°F")
print(f"{celsius}°C = {Kelvin:.2f}K")
# Out:
# 212.0
# 373.15
# 100°C = 212.00°F
# 100°C = 373.15K

# %% [markdown]
# ::: {.callout-tip title="✅ Solución Ejercicio 1.3" collapse="true"}
# ```python
# celsius = 100
# fahrenheit = celsius * 9/5 + 32
# kelvin = celsius + 273.15
#
# print(f"{celsius}°C = {fahrenheit:.2f}°F")
# print(f"{celsius}°C = {kelvin:.2f}K")
# ```
# :::
#
# ---
#
# ### 🟡 Nivel 2 — Aplicación
#
# #### Ejercicio 2.1: Calculadora de IMC

# %%
# Ejercicio 2.1
# Calcula el Índice de Masa Corporal (IMC)
# Fórmula: IMC = peso(kg) / altura(m)²
#
# Mostrá:
# - El IMC redondeado a 1 decimal
# - Si el IMC indica: Bajo peso (<18.5), Normal (18.5-24.9),
#   Sobrepeso (25-29.9), u Obesidad (>=30)
#
# Nota: Para el nivel 2 del if/elif, podés simplemente
#       imprimir el valor y el rango, sin la lógica condicional aún.

peso = 70    # kg
altura = 1.75  # metros

# Calculá el IMC:
imc = peso / altura ** 2

print(f"Peso: {peso} kg")
print(f"Altura: {altura} m")
print(f"IMC: {imc:.1f}")
# ¿En qué rango cae? Verificalo manualmente con los valores de referencia
#IMC Normal
# Out:
# Peso: 70 kg
# Altura: 1.75 m
# IMC: 22.9

# %% [markdown]
# ::: {.callout-tip title="✅ Solución Ejercicio 2.1" collapse="true"}
# ```python
# peso = 70
# altura = 1.75
# imc = peso / altura ** 2
#
# print(f"Peso: {peso} kg")
# print(f"Altura: {altura} m")
# print(f"IMC: {imc:.1f}")
# print(f"IMC referencia: Bajo(<18.5) | Normal(18.5-24.9) | Sobrepeso(25-29.9) | Obesidad(>=30)")
# ```
# Con `imc = 22.9`, el resultado es Normal.
# :::
#
# #### Ejercicio 2.2: Tabla de Multiplicar

# %%
# Ejercicio 2.2
# Sin usar bucles (los veremos en el capítulo 4),
# imprimir los primeros 5 múltiplos de un número usando print() y f-strings.
#
# Output esperado para numero = 7:
# 7 × 1 = 7
# 7 × 2 = 14
# 7 × 3 = 21
# 7 × 4 = 28
# 7 × 5 = 35

numero = 7

# Tu código aquí (repetir el patrón 5 veces):
print(numero * 1)
print(numero * 2)
print(numero * 3)
print(numero * 4)
print(numero * 5)
print(numero * 6)
print(numero * 7)
print(numero * 8)
print(numero * 9)
print(numero * 10)

print(f"{numero} × 1 = {numero * 1}")
print(f"{numero} × 2 = {numero * 2}")
print(f"{numero} × 3 = {numero * 3}")
print(f"{numero} × 4 = {numero * 4}")
print(f"{numero} × 5 = {numero * 5}")

# %% [markdown]
# ::: {.callout-tip title="✅ Solución Ejercicio 2.2" collapse="true"}
# ```python
# numero = 7
# print(f"{numero} × 1 = {numero * 1}")
# print(f"{numero} × 2 = {numero * 2}")
# print(f"{numero} × 3 = {numero * 3}")
# print(f"{numero} × 4 = {numero * 4}")
# print(f"{numero} × 5 = {numero * 5}")
# ```
# En el capítulo 4 veremos cómo hacer esto con un `for` en una sola línea.
# :::
#
# #### Ejercicio 2.3: Separador Visual Dinámico

# %%
# Ejercicio 2.3
# En Python, los strings soportan multiplicación: "=" * 10 → "=========="
# Usá esto para crear una función de separador visual.
#
# Creá variables para:
# - titulo: el texto del título
# - ancho: ancho total del separador (ej: 50)
# - caracter: el caracter del borde (ej: "=")
#
# Output esperado:
# ==================================================
#               REPORTE MENSUAL
# ==================================================

titulo = "REPORTE MENSUAL"
ancho = 50
caracter = "="

# Tu código aquí:
titulo = "REPORTE MENSUAL"
ancho = 50
caracter = "="

separador = caracter * ancho
print (separador)
print (titulo) #no supe como poner el titulo centrado
print (separador)
# Out:
# ...
# REPORTE MENSUAL
# ...

# %% [markdown]
# ::: {.callout-tip title="✅ Solución Ejercicio 2.3" collapse="true"}
# ```python
# titulo = "REPORTE MENSUAL"
# ancho = 50
# caracter = "="
#
# separador = caracter * ancho
# titulo_centrado = titulo.center(ancho)
#
# print(separador)
# print(titulo_centrado)
# print(separador)
# ```
# :::
#
# ---
#
# ### 🔴 Nivel 3 — Integración
#
# #### Ejercicio 3.1: Calculadora Geométrica Completa

# %%
# Ejercicio 3.1
# Dado un radio, calculá y mostrá en un reporte bien formateado:
# - Área del círculo
# - Perímetro (circunferencia)
# - Área de la esfera con ese radio: 4 × π × r²
# - Volumen de la esfera: (4/3) × π × r³
#
# Usá math.pi para mayor precisión
# Todos los resultados con 4 decimales

import math

radio = 5

# Tu código aquí:
area_del_circulo = math.pi * radio ** 2
perimetro_circulo = 2 * math.pi * radio
area_de_esfera = 4 * math.pi * radio ** 2
volumen_de_esfera = (4/3) * math.pi * radio ** 3
print(area_del_circulo)
print (perimetro_circulo)
print (area_de_esfera)
print(volumen_de_esfera)

#no entendí como hacer que sólo fueran 4 decimales
# Out:
# 78.53981633974483
# 31.41592653589793
# 314.1592653589793
# 523.5987755982989

# %% [markdown]
# ::: {.callout-tip title="✅ Solución Ejercicio 3.1" collapse="true"}
# ```python
# import math
#
# radio = 5
#
# area_circulo     = math.pi * radio ** 2
# perimetro        = 2 * math.pi * radio
# area_esfera      = 4 * math.pi * radio ** 2
# volumen_esfera   = (4/3) * math.pi * radio ** 3
#
# print("=" * 45)
# print(f"{'GEOMETRÍA PARA RADIO = ' + str(radio):^45}")
# print("=" * 45)
# print(f"{'Área del círculo:':<25} {area_circulo:>12.4f}")
# print(f"{'Perímetro:':<25} {perimetro:>12.4f}")
# print(f"{'Área de la esfera:':<25} {area_esfera:>12.4f}")
# print(f"{'Volumen de la esfera:':<25} {volumen_esfera:>12.4f}")
# print("=" * 45)
# ```
# :::
#
# #### Ejercicio 3.2: Conversor de Unidades Múltiple

# %%
# Ejercicio 3.2
# Dado un valor en kilómetros, convertilo a:
# - Metros (× 1000)
# - Centímetros (× 100000)
# - Millas (÷ 1.60934)
# - Pies (× 3280.84)
# - Pulgadas (× 39370.1)
#
# Presentalo en una tabla formateada con f-strings
# Alineá los números a la derecha con 2 decimales

km = 42.195   # Maratón!

# Tu código aquí:
metros = km * 1000
centimetros = km * 100000
millas = km / 1.60934
pies = km * 3280.84
pulgadas = km * 39370.1

# Tabla formateada
print(f"{'Unidad':<15}{'Valor':>15}")
print("-" * 30)
print(f"{'Kilómetros':<15}{km:>15.2f}")
print(f"{'Metros':<15}{metros:>15.2f}")
print(f"{'Centímetros':<15}{centimetros:>15.2f}")
print(f"{'Millas':<15}{millas:>15.2f}")
print(f"{'Pies':<15}{pies:>15.2f}")
print(f"{'Pulgadas':<15}{pulgadas:>15.2f}")
# Out:
# Unidad                   Valor
# ------------------------------
# Kilómetros               42.20
# Metros                42195.00
# Centímetros         4219500.00
# Millas                   26.22
# Pies                 138435.04
# Pulgadas            1661221.37

# %% [markdown]
# ::: {.callout-tip title="✅ Solución Ejercicio 3.2" collapse="true"}
# ```python
# km = 42.195
#
# metros      = km * 1000
# centimetros = km * 100000
# millas      = km / 1.60934
# pies        = km * 3280.84
# pulgadas    = km * 39370.1
#
# print(f"{'CONVERSIONES PARA':^45}")
# print(f"{km} kilómetros (distancia de un maratón)")
# print("-" * 45)
# print(f"{'Kilómetros:':<20} {km:>15.2f} km")
# print(f"{'Metros:':<20} {metros:>15.2f} m")
# print(f"{'Centímetros:':<20} {centimetros:>15.2f} cm")
# print(f"{'Millas:':<20} {millas:>15.4f} mi")
# print(f"{'Pies:':<20} {pies:>15.2f} ft")
# print(f"{'Pulgadas:':<20} {pulgadas:>15.2f} in")
# ```
# :::
#
# ---
#
# ## 🚀 Mini Proyecto: Reporte de Análisis Básico

# %%
# Mini Proyecto: Reporte de Inversión Simple
# Simula el cálculo de interés compuesto y genera un reporte.
#
# Fórmula: A = P × (1 + r/n)^(n×t)
# Donde:
#   P = capital inicial
#   r = tasa anual (decimal)
#   n = número de veces que se compone por año
#   t = tiempo en años

# Datos de la inversión
nombre_inversor  = "Carlos Mendoza"
capital_inicial  = 10000     # pesos/dólares
tasa_anual       = 0.08      # 8% anual
n_composicion    = 12        # mensual
anos             = 5

# Cálculo
monto_final = capital_inicial * (1 + tasa_anual / n_composicion) ** (n_composicion * anos)
ganancia    = monto_final - capital_inicial
rendimiento = (ganancia / capital_inicial) * 100

# Reporte
print("=" * 50)
print(f"{'REPORTE DE INVERSIÓN':^50}")
print("=" * 50)
print(f"{'Inversor:':<22} {nombre_inversor}")
print("-" * 50)
print(f"{'Capital inicial:':<22} ${capital_inicial:>12,.2f}")
print(f"{'Tasa anual:':<22} {tasa_anual*100:>11.1f}%")
print(f"{'Composición:':<22} {'Mensual':>12}")
print(f"{'Plazo:':<22} {anos:>10} años")
print("-" * 50)
print(f"{'Monto final:':<22} ${monto_final:>12,.2f}")
print(f"{'Ganancia:':<22} ${ganancia:>12,.2f}")
print(f"{'Rendimiento total:':<22} {rendimiento:>11.1f}%")
print("=" * 50)
# Out:
# ...
#                REPORTE DE INVERSIÓN
# ...
# Inversor:              Carlos Mendoza
# --------------------------------------------------
# Capital inicial:       $   10,000.00
# Tasa anual:                    8.0%
# Composición:                Mensual
# Plazo:                          5 años
# --------------------------------------------------
# Monto final:           $   14,898.46
# Ganancia:              $    4,898.46
# Rendimiento total:            49.0%
# ...

# %% [markdown]
# ---
#
# ## 🏆 Desafíos
#
# ::: {.callout-warning title="Desafío 1 — Segundos en el Universo"}
# La edad estimada del universo es 13.8 mil millones de años.
# Calculá cuántos segundos tiene el universo.
# Hint: 1 año ≈ 365.25 días (incluir años bisiestos)
# Mostrá el resultado en notación científica con 3 decimales: `f"{valor:.3e}"`
# :::
#
# ::: {.callout-warning title="Desafío 2 — Precisión Arbitraria"}
# Calculá `2**1000` y `factorial(50)` en Python.
# Comparalo mentalmente con R: en R, `2^1000` retorna `Inf` en modo double.
# Python maneja enteros de precisión ilimitada.
# ¿Cuántos dígitos tiene `2**1000`? Usá `len(str(2**1000))`.
# :::
#
# ::: {.callout-warning title="Desafío 3 — Reporte Complejo"}
# Extendé el mini proyecto de inversión para mostrar el valor del capital
# al final de cada año (5 líneas), calculando manualmente para t=1, t=2, ..., t=5.
# Formatéalo como tabla con columnas: Año | Capital | Ganancia | Rendimiento %
# :::
#
# ::: {.callout-warning title="Desafío 4 — Diferencia R/Python"}
# En R, `5 / 2L` retorna `2.5` (L fuerza integer en R).
# En Python, `5 / 2` también retorna `2.5`.
# Pero `5 // 2` retorna `2`.
# Experimentá: ¿qué tipo retorna `5 // 2.0`? ¿Y `5 % 2.0`?
# ¿Qué conclusión sacás sobre los tipos en operaciones mixtas?
# :::
#
# ---
#
# ## 📝 Autoevaluación
#
# | Pregunta | Tu Respuesta |
# |---|---|
# | ¿Qué función muestra texto en pantalla? | |
# | ¿Cómo escribes un comentario de una línea? | |
# | ¿Qué operador se usa para potencias? | |
# | ¿Diferencia entre `/` y `//`? | |
# | ¿Cómo se escribe `TRUE` de R en Python? | |
# | ¿Por qué `0.1 + 0.2 != 0.3`? | |
# | ¿Cómo se asigna en Python vs R? | |
# | ¿Qué hace `print("ab", sep="-")` en Python? | |
# | ¿Qué es un f-string? Ejemplo equivalente en R. | |
# | ¿Cómo se documentan funciones en Python vs R? | |
#
# ---
#
# ## 🗒️ Resumen del Capítulo
#
# | Concepto | R | Python |
# |---|---|---|
# | Salida en pantalla | `cat()`, `print()` | `print()` |
# | Asignación | `<-` | `=` |
# | Booleanos | `TRUE`/`FALSE` | `True`/`False` |
# | Nulo | `NULL` | `None` |
# | Potencia | `^` o `**` | `**` (solo) |
# | División entera | `%/%` | `//` |
# | Módulo | `%%` | `%` |
# | Interpolación | `glue()`, `sprintf()` | f-strings |
# | Estilo de nombres | `snake_case` o `camelCase` | `snake_case` (PEP 8) |
# | Documentación | Roxygen `#'` (antes) | Docstring `"""` (dentro) |
# | Índices | Desde **1** | Desde **0** |
# | Bloques de código | `{ }` | Indentación |
#
# > **Próximo capítulo:** Variables y Tipos de Datos — Strings, listas y la diferencia con los vectores de R.

# %%
#Desafío 1
# Edad del universo
años = 13.8e9  # 13.8 mil millones

dias_por_año = 365.25
horas_por_dia = 24
minutos_por_hora = 60
segundos_por_minuto = 60

segundos = años * dias_por_año * horas_por_dia * minutos_por_hora * segundos_por_minuto

print(f"Segundos en el universo: {segundos:.3e}")
#4.355e+17
# Out:
# Segundos en el universo: 4.355e+17

# %%
#Desafío 2
import math

potencia = 2**1000
factorial_50 = math.factorial(50)


digitos = len(str(potencia)) #cantidad de digitos

print(f"2**1000 = {potencia}")
print(f"\nFactorial(50) = {factorial_50}")
print(f"\nCantidad de dígitos en 2**1000: {digitos}")
# Out:
# 2**1000 = 
#
# Factorial(50) = 30414093201713378043612608166064768844377641568960512000000000000
#
# Cantidad de dígitos en 2**1000: 302

# %%
#Desafio 3
capital_inicial = 10000
tasa = 0.10  # 10%

print(f"{'Año':<10}{'Capital':>15}{'Ganancia':>15}{'Rendimiento %':>20}")
print("-" * 60)

capital = capital_inicial

for año in range(1, 6):
    ganancia = capital * tasa
    capital_final = capital + ganancia
    rendimiento = tasa * 100

    print(f"{año:<10}{capital_final:>15.2f}{ganancia:>15.2f}{rendimiento:>20.2f}")
# Out:
# Año               Capital       Ganancia       Rendimiento %
# ------------------------------------------------------------
# 1                11000.00        1000.00               10.00
# 2                11000.00        1000.00               10.00
# 3                11000.00        1000.00               10.00
# 4                11000.00        1000.00               10.00
# 5                11000.00        1000.00               10.00

# %%
#Desafío 4

# División entera c/ float
print(type(5 // 2.0))  # tipo de dato

# Módulo c/ float
print(type(5 % 2.0))

# Valores
print(5 // 2.0)
print(5 % 2.0)
# Out:
# <class 'float'>
# <class 'float'>
# 2.0
# 1.0
